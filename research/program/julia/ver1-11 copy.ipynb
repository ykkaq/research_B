# %%
using Pkg;
Pkg.add("IntervalArithmetic")
Pkg.add("ForwardDiff")
Pkg.add("DifferentialEquations")
Pkg.add("Plots")
Pkg.add("FFTW")
Pkg.add("GenericFFT")
Pkg.status()
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\yu-ki\.julia\environments\v1.11\Project.toml`
#     Updating `C:\Users\yu-ki\.julia\environments\v1.11\Manifest.toml`
#   [7d9f7c33] + Accessors v0.1.39
# ⌃ [4fba245c] ↑ ArrayInterface v7.5.1 ⇒ v7.7.1
#   [4c555306] ↑ ArrayLayouts v1.10.4 ⇒ v1.11.0
#   [6e4b80f9] - BenchmarkTools v1.5.0
#   [9e997f8a] - ChangesOfVariables v0.1.9
#   [523fee87] - CodecBzip2 v0.8.4
#   [a33af91c] + CompositionsBase v0.1.2
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [b429d917] - DensityInterface v0.4.0
#   [77a26b50] ↑ DiffEqNoiseProcess v5.19.0 ⇒ v5.24.0
#   [d4d017d3] ↑ ExponentialUtilities v1.25.0 ⇒ v1.27.0
# ⌃ [6a86dc24] ↑ FiniteDiff v2.22.0 ⇒ v2.23.1
#   [50d2b5c4] - Lazy v0.15.1
# ⌃ [7ed4a6bd] ↓ LinearSolve v2.14.1 ⇒ v2.10.0
#   [2ab3a3ac] ↑ LogExpFunctions v0.3.28 ⇒ v0.3.29
#   [b8f27783] - MathOptInterface v1.34.0
#   [d8a4904e] - MutableArithmetics v1.6.0
#   [d236fae5] ↑ PreallocationTools v0.4.12 ⇒ v0.4.24
#   [f2c3362d] ↑ RecursiveFactorization v0.2.22 ⇒ v0.2.23
#   [7e49a35a] ↑ RuntimeGeneratedFunctions v0.5.12 ⇒ v0.5.13
#   [c0aeaf25] ↑ SciMLOperators v0.3.7 ⇒ v0.3.12
# ⌅ [aedffcd0] ↑ Static v0.8.9 ⇒ v0.8.10
#   [0d7ed370] ↑ StaticArrayInterface v1.6.0 ⇒ v1.8.0
#   [10745b16] + Statistics v1.11.1
#   [d5829a12] ↑ TriangularSolve v0.1.20 ⇒ v0.2.1
# ⌅ [fb77eaff] ↑ Sundials_jll v5.2.1+0 ⇒ v5.2.3+0
#   [0dad84c5] ↑ ArgTools v1.1.1 ⇒ v1.1.2
#   [56f22d72] ~ Artifacts ⇒ v1.11.0
#   [2a0f44e3] ~ Base64 ⇒ v1.11.0
#   [ade2ca70] ~ Dates ⇒ v1.11.0
#   [8ba89e20] ~ Distributed ⇒ v1.11.0
#   [7b1f6079] ~ FileWatching ⇒ v1.11.0
#   [9fa8497b] ~ Future ⇒ v1.11.0
#   [b77e0a4c] ~ InteractiveUtils ⇒ v1.11.0
#   [4af54fe1] ~ LazyArtifacts ⇒ v1.11.0
#   [b27032c2] ↑ LibCURL v0.6.3 ⇒ v0.6.4
#   [76f85450] ~ LibGit2 ⇒ v1.11.0
#   [8f399da3] ~ Libdl ⇒ v1.11.0
#   [37e2e46d] ~ LinearAlgebra ⇒ v1.11.0
#   [56ddb016] ~ Logging ⇒ v1.11.0
#   [d6f4376e] ~ Markdown ⇒ v1.11.0
#   [a63ad114] ~ Mmap ⇒ v1.11.0
#   [44cfe95a] ↑ Pkg v1.8.0 ⇒ v1.11.0
#   [de0858da] ~ Printf ⇒ v1.11.0
#   [9abbd945] - Profile
#   [3fa0cd96] ~ REPL ⇒ v1.11.0
#   [9a3f8284] ~ Random ⇒ v1.11.0
#   [9e88b42a] ~ Serialization ⇒ v1.11.0
#   [1a1011a3] ~ SharedArrays ⇒ v1.11.0
#   [6462fe0b] ~ Sockets ⇒ v1.11.0
#   [2f01184e] ~ SparseArrays ⇒ v1.11.0
#   [f489334b] + StyledStrings v1.11.0
#   [fa267f1f] ↑ TOML v1.0.0 ⇒ v1.0.3
#   [a4e569a6] ↓ Tar v1.10.1 ⇒ v1.10.0
#   [8dfed614] ~ Test ⇒ v1.11.0
#   [cf7118a7] ~ UUIDs ⇒ v1.11.0
#   [4ec0a83e] ~ Unicode ⇒ v1.11.0
#   [e66e0078] ↑ CompilerSupportLibraries_jll v1.0.1+0 ⇒ v1.1.1+0
#   [deac9b47] ↑ LibCURL_jll v7.84.0+0 ⇒ v8.6.0+0
#   [e37daf67] + LibGit2_jll v1.7.2+0
#   [29816b5a] ↑ LibSSH2_jll v1.10.2+0 ⇒ v1.11.0+1
#   [c8ffd9c3] ↑ MbedTLS_jll v2.28.0+0 ⇒ v2.28.6+0
#   [14a3606d] ↑ MozillaCACerts_jll v2022.2.1 ⇒ v2023.12.12
#   [4536629a] ↑ OpenBLAS_jll v0.3.20+0 ⇒ v0.3.27+1
#   [05823500] ↑ OpenLibm_jll v0.8.1+0 ⇒ v0.8.1+2
#   [efcefdf7] ↑ PCRE2_jll v10.40.0+0 ⇒ v10.42.0+1
#   [bea87d4a] ↑ SuiteSparse_jll v5.10.1+0 ⇒ v7.7.0+0
#   [83775a58] ↑ Zlib_jll v1.2.12+3 ⇒ v1.2.13+1
#   [8e850b90] ↑ libblastrampoline_jll v5.1.1+0 ⇒ v5.11.0+0
#   [8e850ede] ↑ nghttp2_jll v1.48.0+0 ⇒ v1.59.0+0
#   [3f19e933] ↑ p7zip_jll v17.4.0+0 ⇒ v17.4.0+2
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#    6685.2 ms  ✓ Distances
#    5510.6 ms  ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#    4168.2 ms  ✓ RuntimeGeneratedFunctions
#    4147.1 ms  ✓ Static
#    4140.8 ms  ✓ ArrayInterface
#    4157.5 ms  ✓ FixedPointNumbers
#    4135.0 ms  ✓ LogExpFunctions
#    4127.8 ms  ✓ Sundials_jll
#    1013.2 ms  ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#    1390.0 ms  ✓ StaticArrays → StaticArraysChainRulesCoreExt
#    1390.9 ms  ✓ BitTwiddlingConvenienceFunctions
#    1600.9 ms  ✓ Distances → DistancesSparseArraysExt
#    1665.2 ms  ✓ Distances → DistancesChainRulesCoreExt
#    1084.0 ms  ✓ ArrayInterface → ArrayInterfaceGPUArraysCoreExt
#    1001.9 ms  ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#    2568.8 ms  ✓ CPUSummary
#    1370.7 ms  ✓ LogExpFunctions → LogExpFunctionsInverseFunctionsExt
#    3547.5 ms  ✓ StaticArrayInterface
#    2752.7 ms  ✓ SciMLOperators
#    2818.2 ms  ✓ ColorTypes
#    2433.2 ms  ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#    1807.0 ms  ✓ HostCPUFeatures
#    1666.6 ms  ✓ FiniteDiff
#    3253.0 ms  ✓ StatsBase
#    3990.3 ms  ✓ SpecialFunctions
#    8003.4 ms  ✓ Graphs
#    3188.7 ms  ✓ PolyesterWeave
#    4144.0 ms  ✓ RecursiveArrayTools
#    3702.9 ms  ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#    2688.4 ms  ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#    4049.0 ms  ✓ CloseOpenIntervals
#    4314.7 ms  ✓ LayoutPointers
#    4230.0 ms  ✓ ColorTypes → StyledStringsExt
#   19478.9 ms  ✓ ArrayLayouts
#    7224.8 ms  ✓ SciMLOperators → SciMLOperatorsSparseArraysExt
#    7317.4 ms  ✓ SciMLOperators → SciMLOperatorsStaticArraysCoreExt
#    5699.8 ms  ✓ FiniteDiff → FiniteDiffStaticArraysExt
#    7076.3 ms  ✓ ColorVectorSpace
#    2833.3 ms  ✓ LevyArea
#    4595.4 ms  ✓ HypergeometricFunctions
#    7910.1 ms  ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#    3651.1 ms  ✓ ArrayLayouts → ArrayLayoutsSparseArraysExt
#    4326.5 ms  ✓ VertexSafeGraphs
#   11674.4 ms  ✓ Colors
#    4912.1 ms  ✓ StrideArraysCore
#    4498.2 ms  ✓ ColorVectorSpace → SpecialFunctionsExt
#    8327.9 ms  ✓ ForwardDiff
#    6470.3 ms  ✓ StatsFuns
#   13267.5 ms  ✓ Polyester
#   10281.0 ms  ✓ PreallocationTools
#   10381.9 ms  ✓ ForwardDiff → ForwardDiffStaticArraysExt
#   14077.2 ms  ✓ ColorSchemes
#   18877.4 ms  ✓ VectorizationBase
#    9999.1 ms  ✓ NLSolversBase
#    2645.5 ms  ✓ StatsFuns → StatsFunsInverseFunctionsExt
#    3043.2 ms  ✓ FastBroadcast
#    4289.9 ms  ✓ StatsFuns → StatsFunsChainRulesCoreExt
#   21807.1 ms  ✓ SciMLBase
#    4757.9 ms  ✓ SLEEFPirates
#    5851.6 ms  ✓ LineSearches
#   12469.3 ms  ✓ SparseDiffTools
#   12626.9 ms  ✓ Distributions
#   35170.9 ms  ✓ BandedMatrices
#    9508.2 ms  ✓ NLsolve
#    8884.0 ms  ✓ Distributions → DistributionsTestExt
#    9710.6 ms  ✓ SparseDiffTools → SparseDiffToolsPolyesterExt
#   23113.3 ms  ✓ PlotUtils
#   13197.8 ms  ✓ Optim
#   15750.5 ms  ✓ Distributions → DistributionsChainRulesCoreExt
#   11893.8 ms  ✓ ArrayInterface → ArrayInterfaceBandedMatricesExt
#   11176.3 ms  ✓ FiniteDiff → FiniteDiffBandedMatricesExt
#   14752.0 ms  ✓ BandedMatrices → BandedMatricesSparseArraysExt
#   34435.7 ms  ✓ DiffEqBase
#   16952.2 ms  ✓ RecipesPipeline
#   17484.3 ms  ✓ PlotThemes
#   12563.8 ms  ✓ DiffEqBase → DiffEqBaseDistributionsExt
#   13051.5 ms  ✓ DiffEqBase → DiffEqBaseUnitfulExt
#   13693.1 ms  ✓ SciMLNLSolve
#   14935.6 ms  ✓ DiffEqCallbacks
#    7541.1 ms  ✓ SteadyStateDiffEq
#   15987.3 ms  ✓ JumpProcesses
#   58657.9 ms  ✓ LoopVectorization
#   17506.0 ms  ✓ SimpleNonlinearSolve
#   18303.1 ms  ✓ DiffEqNoiseProcess
#  105075.1 ms  ✓ ExponentialUtilities
#    8979.3 ms  ✓ JumpProcesses → JumpProcessFastBroadcastExt
#    9787.8 ms  ✓ LoopVectorization → SpecialFunctionsExt
#   10070.7 ms  ✓ LoopVectorization → ForwardDiffExt
#   10051.8 ms  ✓ TriangularSolve
#    8615.3 ms  ✓ ExponentialUtilities → ExponentialUtilitiesStaticArraysExt
#   42608.3 ms  ✓ Sundials
#   17395.6 ms  ✓ RecursiveFactorization
#   48845.9 ms  ✓ LinearSolve
#  104232.2 ms  ✓ Plots

# %%
using LinearAlgebra, DifferentialEquations, FFTW
include("FourierChebyshev.jl")

# van der Pol方程式
function vanderpol(du, u, μ, t)
  x, y = u
  du[1] = y
  du[2] = μ * (1 - x^2) * y - x
end

# 畳み込み
function powerconvfourier(a::Vector{Complex{T}}, p) where {T}
  println("Input: ", size(a))
  M = Int((length(a) + 1) / 2)
  N = (p - 1) * M
  ta = [zeros(N, 1); a; zeros(N, 1)] # 1. Padding zeros: size(ta) = 2pM-1
  tb = ifft(ifftshift(ta)) # 2. IFFT of ta
  tbᵖ = tb .^ p # 3. tb*^tb
  cᵖ = fftshift(fft(tbᵖ)) * (2.0 * p * M - 1)^(p - 1)
  return cᵖ[N+1:end-N], cᵖ[p:end-(p-1)]# return (truncated, full) version
end

# F^(N)(x_n)
function F_fourier(x, μ, η₀)
  DF[1, 2:end] .= 1
  DF[2:end, 1] = (-2 * ω * k .^ 2 - μ * im * k) .* a + μ * im * k .* a³ / 3

  (~, a2) = powerconvfourier(a, 2)

  M = zeros(ComplexF64, 2 * N - 1, 2 * N - 1)

  for j = (-N+1):(N-1)
    M[k.+N, j+N] = μ * im * k * ω .* a2[k.-j.+(2*N-1)]
  end

  L = diagm(-k .^ 2 * ω^2 - μ * im * k * ω .+ 1)

  DF[2:end, 2:end] = L + M
  return DF
end

# a function of  fourier coeffs
function odefouriercoeffs(f, N, I, n=1)
  a = I[1]
  b = I[2]
  # x_j: equidistance node points
  h = (b - a) / (2N - 1)
  j = 0:2N-2
  xⱼ = a .+ j * h
  # f_j: function values on node points
  fⱼ = f(xⱼ)[n, :]
  return (fftshift(fft(fⱼ))) / (2 * N - 1)
end

# たぶん，初期値設定
u_0 = [0.0; 2.0]
tspan = (0.0, 300)
μ = 1.0
prob = ODEProblem(vanderpol, u_0, tspan, μ)
sol = solve(prob, Tsit5(), reltol=1e-8, abstol=1e-8)
u = hcat(sol.u...)
ind = floor(Int, length(sol.t) / 2)

# おおよその周期
#a = 30
#b = 36.55
a = 30
app_period = 6.55
timestep = 0.1

f_tmp = sol(a+app_period/2:timestep:a+3*app_period/2)
find_period = abs.(f_tmp .- sol(a))
(~, ind) = findmin(find_period[1, :])
b = a + app_period / 2 + timestep * (ind - 1)
#calc fouriercoeffs
N = 50 # size of Fourier
println("size of Fourier = $N")
a_0 = odefouriercoeffs(sol, N, [a, b])

include("IntervalFunctions.jl")
# Initial value of Newton method
η_0 = 0.0
x = [2 * pi / (b - a); a_0]

# Newton iteration
tol = 5e-12
F = F_fourier(x, μ, η_0)
println("Before step #1, ||F||_1 = $(norm(F,1))")
num_itr = 0

while num_itr ≤ 100
  global x = x - DF_fourier(x, μ) \ F
  global num_itr += 1
  global F = F_fourier(x, μ, η_0)
  # println("After step #$(num_itr), ||F||_1 = $(norm(F,1))")
  if norm(F, 1) < tol
    break
  end
end

# A^(N)
ix = map(Interval, x)
iω̄ = map(Interval, real(x[1]))
iā = map(Interval, x[2:end])

function DF_fourier(x::Vector{Complex{Interval{T}}}, μ) where {T}
  N = Int((length(x)) / 2)
  ω = x[1]
  a = x[2:end]
  k = (-N+1):(N-1)
  (a³, ~) = powerconvfourier(a, 3)
  DF = zeros(Complex{Interval{T}}, 2N, 2N)
  DF[1, 2:end] .= 1
  DF[2:end, 1] = (-2 * ω * k .^ 2 - μ * im * k) .* a + μ * im * k .* a³ / 3
  (~, a2) = powerconvfourier(a, 2)
  M = zeros(Complex{Interval{T}}, 2 * N - 1, 2 * N - 1)
  for j = (-N+1):(N-1)
    M[k.+N, j+N] = μ * im * k * ω .* a2[k.-j.+(2*N-1)]
  end
  L = diagm(-k .^ 2 * ω^2 - μ * im * k * ω .+ 1)
  DF[2:end, 2:end] = L + M
  return DF
end
# Out:
# ┌ Warning: attempting to remove probably stale pidfile
# │   path = "C:\\Users\\yu-ki\\.julia\\compiled\\v1.11\\NonlinearSolve\\8YWaI_DFwFb.ji.pidfile"
# └ @ FileWatching.Pidfile C:\Users\yu-ki\.julia\juliaup\julia-1.11.2+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:249
# size of Fourier = 50
# UndefVarError: `DF` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] F_fourier(x::Vector{ComplexF64}, μ::Float64, η₀::Float64)
#
#    @ Main d:\workspace_win\research_B\research\program\julia\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W1sZmlsZQ==.jl:25
#
#  [2] top-level scope
#
#    @ d:\workspace_win\research_B\research\program\julia\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W1sZmlsZQ==.jl:87

# %%
iDF = DF_fourier(ix, μ);
iA = inv(iDF) # map(Interval,inv(mid.(iDF)))


## =======================
## I get a and omega by x.
## =======================
"""
println("x = $x")
println("μ = $μ")
println("N = $N")1

μ
"""

omega = x[1]
a = x[2:end]
mu = μ

# lambda 行列
lambda_array = zeros(ComplexF64, 3 * N, 3 * N) # Change to ComplexF64
lambda_array_size = size(lambda_array)[1]
for k in 1:lambda_array_size
  kk = k + N - 1
  lambda_array[k, k] = 1 / (-1 * kk^2 * omega^2 - mu * im * kk * omega + 1)
end

# DF[]
DF = DF_fourier(x, mu)
zero_padding = zeros(ComplexF64, Int(1.5 * N))
extend_x = vcat(omega, zero_padding, a, zero_padding)
extend_DF = DF_fourier(extend_x, mu)


# norm_D
DF_bottomright = extend_DF[2N+1:end, 2N+1:end]
D = lambda_array * DF_bottomright
normD = maximum(sum(abs.(D), dims=1))

# norm_C
DF_bottomleft = extend_DF[2N+1:end, 1:2N]
C = lambda_array * DF_bottomleft
normC = maximum(sum(abs.(C), dims=1))

# norm_B
DF_topright = extend_DF[1:2N, 2N+1:end]


println("||D|| = ", normD)
println("||C|| = ", normC)
